# %% [markdown]
# ## jobs_scraper

# %%
import pandas as pd
from jobs_scraper.scraping import JobsScraper

# %%
scraper = JobsScraper(headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'},
                      url = "https://www.indeed.nl/vacatures?q=software+engineer&l=", 
                      pages = 3)

# %%
df = scraper.scrape()

# %%
df.to_csv("jobs_scraped.csv", index=False)

# %%
df
# Out:
#                                                 title           location  \
# 0                 Graduate Software Engineer (London)     Amsterdam Zuid
# 1         Junior API Integration Engineer-Netherlands  Amsterdam Centrum
# 2                                   Software Engineer          Rotterdam
# 3                             Experienced C# Engineer           Nootdorp
# 4   Deep Learning Research Engineer (Qualcomm Rese...          Amsterdam
# 5                               EU Software Developer            Tilburg
# 6                         Principal Software Engineer           Schiphol
# 7                    Lead Software Engineer, Back-End          Amsterdam
# 8                      Autopilot Software QA Engineer          Amsterdam
# 9                            Senior Software Engineer          Amsterdam
# 10                                 Websphere Engineer            Utrecht
# 11                                Simulation Engineer          Nederland
# 12               Software Engineer - Email Automation          Amsterdam
# 13                 Senior Software Engineer, Back-End          Amsterdam
# 14                             Software Test Engineer          Rotterdam
# 15      Software Engineer - New Grad 2021 (Amsterdam)          Amsterdam
# 16                                Microscopy Engineer              Delft
# 17                          Mechanical Engineer (R&D)         Hengelo OV
# 18                             Field Service Engineer            Utrecht
# 19                                    DevOps engineer          Amsterdam
# 20                           Python Software Engineer          Amsterdam
# 21                                  Software Engineer            Boxmeer
# 22                      Software Engineer: Public API          Amsterdam
# 23  Senior Solution Engineer - SD-WAN EMEA (Dell) ...            Utrecht
# 24                                  Software Engineer              Delft
# 25                                Full Stack Engineer          Amsterdam
# 26      Software Engineer, Mobile apps, Group Digital          Amsterdam
# 27       Cyber Security Engineer - Token ID - Level 4          Rotterdam
# 28                                  Software Engineer            Woerden
# 29          Senior Software Engineer - Data Streaming            Utrecht
# 30                              PHP Software Engineer     Werk van thuis
# 31                             Cloud Tooling Engineer            Utrecht
# 32                            HP-Unix System Engineer             Leiden
# 33              Internship - Junior Software Engineer          Amsterdam
# 34        Junior Software Engineer (32-40 hours/week)         Amersfoort
# 35                         Graduate Software Engineer          Amsterdam
# 36                         Software Engineer (Junior)         Veenendaal
# 37  Software Development Engineer Internship – 202...          Amsterdam
# 38                          Robotics engineer (ML/AI)          Amsterdam
# 39           Software Engineer - New Grad (Amsterdam)          Amsterdam
# 40                  Embedded Software Design Engineer          Veldhoven
# 41                                  Software Engineer          Eindhoven
# 42  .NET Software Engineer | Defensie | Nato | Eur...           Randstad
# 43                          Customer Service Engineer          Amsterdam
# 44    Internship Machine Learning (Software) Engineer          Nederland
#
#                                    company  \
# 0                                  Optiver
# 1                           Enterprise Bot
# 2                                Equalture
# 3                                    Fugro
# 4   Qualcomm Technologies Netherlands B.V.
# 5                                    Tesla
# 6                           Liberty Global
# 7                                   Everon
# 8                                    Tesla
# 9                           Tommy Hilfiger
# 10                                Rabobank
# 11          INCONTROL Simulation Solutions
# 12                              WeTransfer
# 13                                  Everon
# 14      Science [&] Technology Corporation
# 15                              Databricks
# 16                               Microsoft
# 17                 Howden Netherlands B.V.
# 18                                    Pall
# 19                              BESTSELLER
# 20                                   iBOOD
# 21                                   Marel
# 22                      Digital Ocean Jobs
# 23                                  VMware
# 24                            Baker Hughes
# 25                             Amberscript
# 26                                    IKEA
# 27                                    Visa
# 28                                    Flex
# 29                                 Bol.com
# 30                       Sandwave Software
# 31                                 Bol.com
# 32                                   SWIFT
# 33                                  Finaps
# 34                     Cablon Medical B.V.
# 35                                   Adyen
# 36                      CoachR Development
# 37          Amzn Dev Ctr (Netherlands) B.V
# 38                               JetBrains
# 39                              Databricks
# 40                                    ASML
# 41                                 Trifork
# 42                  Hello Developers World
# 43                   Keysight Technologies
# 44                      Sensys Gatso Group
#
#                                               summary  \
# 0   Working together, our traders and software eng...
# 1   At Enterprise Bot, we create AI-powered bots t...
# 2   We are looking for a software engineer to help...
# 3   Agile and passionate about software engineerin...
# 4   As a Deep Learning Researcher at Qualcomm, you...
# 5   Collaborate with other cross-functional teams ...
# 6   Support and develop software engineers by prov...
# 7   Your software will handle load balancing and i...
# 8   Experience troubleshooting on both software an...
# 9   Tools: software containerization (Docker), Git...
# 10  You have general knowledge of software develop...
# 11  Provide user support our software users.Suppor...
# 12  At the moment the team consists of a mix data ...
# 13  Experience in engineering low latency software...
# 14  Knowledge with data processing algorithms, con...
# 15  We are hiring software engineers who are passi...
# 16  Microsoft’s verticalized approach involves exc...
# 17  Ervaring met technische software zoals MATLAB;...
# 18  Experience with associated software systems, D...
# 19  We are software engineers, delivering a platfo...
# 20  Experience with Agile software development met...
# 21  We are looking for software engineers, with ba...
# 22  We are looking for engineers to join our API E...
# 23  We look beyond the barriers of compromise to e...
# 24  Have experience with scaled Scrum/Agile softwa...
# 25  We are building SaaS software that enables use...
# 26  Working closely with other software engineers ...
# 27  Fascinated by the future and captivated by tec...
# 28  Design and document software architectures.As ...
# 29  And because you are a great Java engineer with...
# 30  Als onderdeel van marktleider Total Webhosting...
# 31  Therefore, we’re looking for a versatile engin...
# 32  Install software releases of common applicatio...
# 33  Experience with commercial software developmen...
# 34  Do you want to help hospitals worldwide meet h...
# 35  Our engineers are responsible for the full dev...
# 36  As a Software Engineer you will contribute to ...
# 37  Our interns write real software and collaborat...
# 38  JetBrains is a globally operating IT vendor th...
# 39  We are hiring software engineers who are passi...
# 40  Defining software and integration tests to qua...
# 41  Daarom zoeken wij gedreven software engineers ...
# 42  Omdat er vereist is dat de software van de hoo...
# 43  We offer the most precise electronic measureme...
# 44  We have several University level internships a...
#
#                        salary
# 0                        None
# 1                        None
# 2   €3.000 - €4.500 per maand
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
# 10                       None
# 11                       None
# 12                       None
# 13                       None
# 14                       None
# 15                       None
# 16                       None
# 17  €4.000 - €5.250 per maand
# 18                       None
# 19                       None
# 20                €40 per uur
# 21                       None
# 22                       None
# 23                       None
# 24                       None
# 25                       None
# 26                       None
# 27                       None
# 28                       None
# 29                       None
# 30  €2.700 - €3.500 per maand
# 31                       None
# 32                       None
# 33                       None
# 34                       None
# 35                       None
# 36                       None
# 37                       None
# 38                       None
# 39                       None
# 40                       None
# 41                       None
# 42  €3.000 - €6.000 per maand
# 43                       None
# 44                       None
