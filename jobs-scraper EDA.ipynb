# %% [markdown]
# ## jobs_scraper (WIP)

# %%
import pandas as pd
from jobs_scraper.scraping import JobsScraper

# %%
scraper = JobsScraper(headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'},
                      url = "https://www.indeed.nl/vacatures?q=software+engineer&l=", 
                      pages = 3)

# %%
df = scraper.scrape()

# %%
df.to_csv("jobs_scraped.csv", index=False)

# %%
df
# Out:
#                                                 title             location  \
# 0                 Graduate Software Engineer (London)       Amsterdam Zuid
# 1                                   Software Engineer            Rotterdam
# 2                            Senior Software Engineer            Amsterdam
# 3                               EU Software Developer              Tilburg
# 4                    Lead Software Engineer, Back-End            Amsterdam
# 5   Deep Learning Research Engineer (Qualcomm Rese...            Amsterdam
# 6                      Autopilot Software QA Engineer            Amsterdam
# 7         Junior API Integration Engineer-Netherlands    Amsterdam Centrum
# 8                             Experienced C# Engineer             Nootdorp
# 9                Software Engineer - Email Automation            Amsterdam
# 10                        Principal Software Engineer             Schiphol
# ...
